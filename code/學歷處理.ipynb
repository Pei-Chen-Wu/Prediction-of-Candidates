# 2                     專職里長。\n有事不必到我家，打手機到府服務： 0918629668
# 3                              協助弱勢里民，反應里民所需，維護改善里內居家環境。
# 4      1、敦親睦鄰,促進里和諧。\n2、爭取建設,力求里民福利。\n3、熱心服務,關照老弱婦孺。\...
# ...                                                  ...
# 14501  一、呷咱瓊埔村鄉親大家站在一起向鄉、縣政府争取地方建設。二、加強社區全面監視系統以維護地方財...
# 14502  一、監督新建村民集會所之工程進度與品質。二、積極爭取新建集會所之內部各項設施經費。三、落實產...
# 14503                          爭取地方建設、服務村民、綠美化社區、促進地方和諧。
# 14504        一、服務村民。二、水道路修護。三、整理環境衛生。四、關心老人與福利。五、促進社區發展。
# 14505  1.配合公所之政令推動。2.定期消毒及疏通村內水溝,確保環境衛生及提升村民生活品質。3.舉辦...
#
# [14506 rows x 15 columns]

# %% [markdown]
# ## 初步測試

# %% [markdown]
# ### LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
class_le = LabelEncoder( )
class_le.fit( df[ '學歷' ] )
# Out:
# LabelEncoder()

# %%
df[ '學歷' ]  = class_le.transform( df['學歷' ] )

# %%
df
# Out:
#               地區 村里碼   姓名 號次 性別  出生年次        推薦政黨  得票數     得票率 當選註記 是否現任  \
# 0      南投縣南投市龍泉里   1  鄭木桂  1  男  1931  無黨籍及未經政黨推薦  526       1    1    是
# 1      南投縣南投市康壽里   2  田福川  1  男  1956  無黨籍及未經政黨推薦  312  0.3196    0    否
# 2      南投縣南投市康壽里   2  林華騰  2  男  1950  無黨籍及未經政黨推薦  396  0.4057    1    是
# 3      南投縣南投市康壽里   2  吳秋庚  3  男  1954  無黨籍及未經政黨推薦  268  0.2745    0    否
# 4      南投縣南投市三民里   3  蕭承倉  1  男  1961  無黨籍及未經政黨推薦  525       1    1    是
# ...          ...  ..  ... .. ..   ...         ...  ...     ...  ...  ...
# 14501  雲林縣水林鄉欍埔村  21   蘇鐵  3  男  1952  無黨籍及未經政黨推薦  269  0.4777    1    否
# 14502  雲林縣水林鄉塭底村  22  黃志金  1  男  1955  無黨籍及未經政黨推薦  451       1    1    是
# 14503  雲林縣水林鄉後寮村  23  陳正龍  1  男  1964  無黨籍及未經政黨推薦  458       1    1    是
# 14504  雲林縣水林鄉溪墘村  24  蔡錦明  1  男  1951  無黨籍及未經政黨推薦  325  0.4887    0    否
# 14505  雲林縣水林鄉溪墘村  24  高文彬  2  男  1959  無黨籍及未經政黨推薦  340  0.5112    1    是
#
#               編碼    學歷                                                 經歷  \
# 0      370401011  2402  一、南投市農會代表\n二、南投義勇消防隊分隊長\n三、南投巿老人會會長\n四、南投市第14 ...
# 1      370401021   776  1.南投市康壽社區發展協會 總幹事\n2.天鵬旅行社(原川田)總經理\n3.南投縣旅行商業同...
# 2      370401022  1947                         林x光檢驗中心負責人。\n南投市第19屆康壽里里長。
# 3      370401023  2899                                        康壽里十七、十八屆里長
# 4      370401031  2903    1.頂街頭地母委員會主任委員\n2.民防南投分隊顧問團榮譽團長\n3.17屆18屆里長現任里長
# ...          ...   ...                                                ...
# 14501  370520213  1617  第十二屆瓊埔村村長、第十五屆港口宮委員、第十七屆港口宮委員、第十八屆港口宮委員、現任瓊埔村順...
# 14502  370520221  1612                           第18、19屆塭底村村長。港口宮管理委員會委員。
# 14503  370520231  6611                                    後寮村17、18、19屆村長。
# 14504  370520241  2896                                      15、16、17農會代表。
# 14505  370520242  6611             1.水林鄉鄉民代表會第13.15.屆代表。2.水林鄉溪村第18.19屆村長。
#
#                                                       政見
# 0      （一）堅持熱誠服務態度\n（二）重視里內低收入戶及殘障弱勢里民之照顧\n（三）重視老人福利及...
# 1      一、設置關懷爆點,積極關懷·里內獨居老人,外配,愛族的起\n居生活,並辦理里民社會急難救助,...
# 2                     專職里長。\n有事不必到我家，打手機到府服務： 0918629668
# 3                              協助弱勢里民，反應里民所需，維護改善里內居家環境。
# 4      1、敦親睦鄰,促進里和諧。\n2、爭取建設,力求里民福利。\n3、熱心服務,關照老弱婦孺。\...
# ...                                                  ...
# 14501  一、呷咱瓊埔村鄉親大家站在一起向鄉、縣政府争取地方建設。二、加強社區全面監視系統以維護地方財...
# 14502  一、監督新建村民集會所之工程進度與品質。二、積極爭取新建集會所之內部各項設施經費。三、落實產...
# 14503                          爭取地方建設、服務村民、綠美化社區、促進地方和諧。
# 14504        一、服務村民。二、水道路修護。三、整理環境衛生。四、關心老人與福利。五、促進社區發展。
# 14505  1.配合公所之政令推動。2.定期消毒及疏通村內水溝,確保環境衛生及提升村民生活品質。3.舉辦...
#
# [14506 rows x 15 columns]

# %% [markdown]
# ### Mapping

# %%
class_mapping = { '研究所':6, '大學':5, '專科':4,'高中':3,'高職' :3,'國中' : 2 ,'國小':2} #最後無數字者 歸為1（國小以下）

# %%
df[ '學歷' ] = df[ '學歷' ].map(class_mapping)

# %%
df
# Out:
#               地區 村里碼   姓名 號次 性別  出生年次        推薦政黨  得票數     得票率 當選註記 是否現任  \
# 0      南投縣南投市龍泉里   1  鄭木桂  1  男  1931  無黨籍及未經政黨推薦  526       1    1    是
# 1      南投縣南投市康壽里   2  田福川  1  男  1956  無黨籍及未經政黨推薦  312  0.3196    0    否
# 2      南投縣南投市康壽里   2  林華騰  2  男  1950  無黨籍及未經政黨推薦  396  0.4057    1    是
# 3      南投縣南投市康壽里   2  吳秋庚  3  男  1954  無黨籍及未經政黨推薦  268  0.2745    0    否
# 4      南投縣南投市三民里   3  蕭承倉  1  男  1961  無黨籍及未經政黨推薦  525       1    1    是
# ...          ...  ..  ... .. ..   ...         ...  ...     ...  ...  ...
# 14501  雲林縣水林鄉欍埔村  21   蘇鐵  3  男  1952  無黨籍及未經政黨推薦  269  0.4777    1    否
# 14502  雲林縣水林鄉塭底村  22  黃志金  1  男  1955  無黨籍及未經政黨推薦  451       1    1    是
# 14503  雲林縣水林鄉後寮村  23  陳正龍  1  男  1964  無黨籍及未經政黨推薦  458       1    1    是
# 14504  雲林縣水林鄉溪墘村  24  蔡錦明  1  男  1951  無黨籍及未經政黨推薦  325  0.4887    0    否
# 14505  雲林縣水林鄉溪墘村  24  高文彬  2  男  1959  無黨籍及未經政黨推薦  340  0.5112    1    是
#
#               編碼  學歷                                                 經歷  \
# 0      370401011 NaN  一、南投市農會代表\n二、南投義勇消防隊分隊長\n三、南投巿老人會會長\n四、南投市第14 ...
# 1      370401021 NaN  1.南投市康壽社區發展協會 總幹事\n2.天鵬旅行社(原川田)總經理\n3.南投縣旅行商業同...
# 2      370401022 NaN                         林x光檢驗中心負責人。\n南投市第19屆康壽里里長。
# 3      370401023 NaN                                        康壽里十七、十八屆里長
# 4      370401031 NaN    1.頂街頭地母委員會主任委員\n2.民防南投分隊顧問團榮譽團長\n3.17屆18屆里長現任里長
# ...          ...  ..                                                ...
# 14501  370520213 NaN  第十二屆瓊埔村村長、第十五屆港口宮委員、第十七屆港口宮委員、第十八屆港口宮委員、現任瓊埔村順...
# 14502  370520221 NaN                           第18、19屆塭底村村長。港口宮管理委員會委員。
# 14503  370520231 NaN                                    後寮村17、18、19屆村長。
# 14504  370520241 NaN                                      15、16、17農會代表。
# 14505  370520242 NaN             1.水林鄉鄉民代表會第13.15.屆代表。2.水林鄉溪村第18.19屆村長。
#
#                                                       政見
# 0      （一）堅持熱誠服務態度\n（二）重視里內低收入戶及殘障弱勢里民之照顧\n（三）重視老人福利及...
# 1      一、設置關懷爆點,積極關懷·里內獨居老人,外配,愛族的起\n居生活,並辦理里民社會急難救助,...
# 2                     專職里長。\n有事不必到我家，打手機到府服務： 0918629668
# 3                              協助弱勢里民，反應里民所需，維護改善里內居家環境。
# 4      1、敦親睦鄰,促進里和諧。\n2、爭取建設,力求里民福利。\n3、熱心服務,關照老弱婦孺。\...
# ...                                                  ...
# 14501  一、呷咱瓊埔村鄉親大家站在一起向鄉、縣政府争取地方建設。二、加強社區全面監視系統以維護地方財...
# 14502  一、監督新建村民集會所之工程進度與品質。二、積極爭取新建集會所之內部各項設施經費。三、落實產...
# 14503                          爭取地方建設、服務村民、綠美化社區、促進地方和諧。
# 14504        一、服務村民。二、水道路修護。三、整理環境衛生。四、關心老人與福利。五、促進社區發展。
# 14505  1.配合公所之政令推動。2.定期消毒及疏通村內水溝,確保環境衛生及提升村民生活品質。3.舉辦...
#
# [14506 rows x 15 columns]

# %% [markdown]
# ## ckip_transformers  NLP Tools

# %%
from ckip_transformers import __version__
from ckip_transformers.nlp import CkipWordSegmenter, CkipPosTagger, CkipNerChunker
print(__version__)
ws_driver = CkipWordSegmenter(level=3)
pos_driver = CkipPosTagger(level=3)
ner_driver = CkipNerChunker(level=3)
# Out:
# 0.2.7

# %%
test = '一、南華大學旅遊管理研究所畢業\n二、南開科技大學畢業\n三、南投高中畢業\n四、南投國中畢業\n五、平和國小畢業'
ws  = ws_driver(test)
pos = pos_driver(ws)
ner = ner_driver(test)
print('斷詞 ： ',ws)
print('詞性標記 ： ',pos)
print('實體辨識 ： ',ner)
# Out:
# Tokenization: 100%|█████████████████████████| 53/53 [00:00<00:00, 175868.76it/s]
# Inference: 100%|██████████████████████████████████| 1/1 [00:00<00:00,  4.13it/s]
# Tokenization: 100%|█████████████████████████| 53/53 [00:00<00:00, 178266.33it/s]
# Inference: 100%|██████████████████████████████████| 1/1 [00:00<00:00,  4.45it/s]
# Tokenization: 100%|█████████████████████████| 53/53 [00:00<00:00, 239030.23it/s]
# Inference: 100%|██████████████████████████████████| 1/1 [00:00<00:00,  4.22it/s]
# 斷詞 ：  [['一'], ['、'], ['南'], ['華'], ['大'], ['學'], ['旅'], ['遊'], ['管'], ['理'], ['研'], ['究'], ['所'], ['畢'], ['業'], ['\n'], ['二'], ['、'], ['南'], ['開'], ['科'], ['技'], ['大'], ['學'], ['畢'], ['業'], ['\n'], ['三'], ['、'], ['南'], ['投'], ['高'], ['中'], ['畢'], ['業'], ['\n'], ['四'], ['、'], ['南'], ['投'], ['國'], ['中'], ['畢'], ['業'], ['\n'], ['五'], ['、'], ['平'], ['和'], ['國'], ['小'], ['畢'], ['業']]
# 詞性標記 ：  [['Neu'], ['PAUSECATEGORY'], ['Ncd'], ['Nb'], ['VH'], ['VC'], ['Na'], ['VCL'], ['VE'], ['Na'], ['VE'], ['D'], ['D'], ['VH'], ['Na'], ['WHITESPACE'], ['Neu'], ['PAUSECATEGORY'], ['Ncd'], ['VC'], ['Na'], ['Na'], ['VH'], ['VC'], ['VH'], ['Na'], ['WHITESPACE'], ['Neu'], ['PAUSECATEGORY'], ['Ncd'], ['VC'], ['Nb'], ['Ncd'], ['VH'], ['Na'], ['WHITESPACE'], ['Neu'], ['PAUSECATEGORY'], ['Ncd'], ['VC'], ['Na'], ['Ncd'], ['VH'], ['Na'], ['WHITESPACE'], ['Neu'], ['PAUSECATEGORY'], ['VH'], ['P'], ['Na'], ['VH'], ['VH'], ['Na']]
# 實體辨識 ：  [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [NerToken(word='二', ner='ORDINAL', idx=(0, 1))], [], [], [], [], [], [], [], [], [], [], [NerToken(word='三', ner='ORDINAL', idx=(0, 1))], [], [], [], [], [], [], [], [], [NerToken(word='四', ner='ORDINAL', idx=(0, 1))], [], [], [], [], [], [], [], [], [NerToken(word='五', ner='ORDINAL', idx=(0, 1))], [], [], [], [], [], [], []]

# %%
def pack_ws_pos_sentece(sentence_ws, sentence_pos):
    assert len(sentence_ws) == len(sentence_pos)
    res = []
    for word_ws, word_pos in zip(sentence_ws, sentence_pos):
        res.append(f"{word_ws}({word_pos})")
    return "\u3000".join(res)

# %%
for sentence, sentence_ws, sentence_pos, sentence_ner in zip(test, ws, pos, ner):
    print(sentence)
    print(pack_ws_pos_sentece(sentence_ws, sentence_pos))
    for entity in sentence_ner:
        print(entity)
    print()
# Out:
# 一
# 一(Neu)
#
# 、
# 、(PAUSECATEGORY)
#
# 南
# 南(Ncd)
#
# 華
# 華(Nb)
#
# 大
# 大(VH)
#
# 學
# 學(VC)
#
# 旅
# 旅(Na)
#
# 遊
# 遊(VCL)
#
# 管
# 管(VE)
#
# 理
# 理(Na)
#
# 研
# 研(VE)
#
# 究
# 究(D)
#
# 所
# 所(D)
#
# 畢
# 畢(VH)
#
# 業
# 業(Na)
#
#
#
#
# (WHITESPACE)
#
# 二
# 二(Neu)
# NerToken(word='二', ner='ORDINAL', idx=(0, 1))
#
# 、
# 、(PAUSECATEGORY)
#
# 南
# 南(Ncd)
#
# 開
# 開(VC)
#
# 科
# 科(Na)
#
# 技
# 技(Na)
#
# 大
# 大(VH)
#
# 學
# 學(VC)
#
# 畢
# 畢(VH)
#
# 業
# 業(Na)
#
#
#
#
# (WHITESPACE)
#
# 三
# 三(Neu)
# NerToken(word='三', ner='ORDINAL', idx=(0, 1))
#
# 、
# 、(PAUSECATEGORY)
#
# 南
# 南(Ncd)
#
# 投
# 投(VC)
#
# 高
# 高(Nb)
#
# 中
# 中(Ncd)
#
# 畢
# 畢(VH)
#
# 業
# 業(Na)
#
#
#
#
# (WHITESPACE)
#
# 四
# 四(Neu)
# NerToken(word='四', ner='ORDINAL', idx=(0, 1))
#
# 、
# 、(PAUSECATEGORY)
#
# 南
# 南(Ncd)
#
# 投
# 投(VC)
#
# 國
# 國(Na)
#
# 中
# 中(Ncd)
#
# 畢
# 畢(VH)
#
# 業
# 業(Na)
#
#
#
#
# (WHITESPACE)
#
# 五
# 五(Neu)
# NerToken(word='五', ner='ORDINAL', idx=(0, 1))
#
# 、
# 、(PAUSECATEGORY)
#
# 平
# 平(VH)
#
# 和
# 和(P)
#
# 國
# 國(Na)
#
# 小
# 小(VH)
#
# 畢
# 畢(VH)
#
# 業
# 業(Na)

# %%
from transformers import (
  BertTokenizerFast,
  AutoModel,
)

tokenizer = BertTokenizerFast.from_pretrained('bert-base-chinese')
model = AutoModel.from_pretrained('ckiplab/bert-base-chinese-ws')
# Out:
# Downloading:   0%|          | 0.00/107k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/263k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/624 [00:00<?, ?B/s]
# Some weights of the model checkpoint at ckiplab/bert-base-chinese-ws were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertModel were not initialized from the model checkpoint at ckiplab/bert-base-chinese-ws and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
tokens = tokenizer.tokenize(test)
ids = tokenizer.convert_tokens_to_ids(tokens)

# %%
print(tokens)
print(ids)
# Out:
# ['一', '、', '南', '華', '大', '學', '旅', '遊', '管', '理', '研', '究', '所', '畢', '業', '二', '、', '南', '開', '科', '技', '大', '學', '畢', '業', '三', '、', '南', '投', '高', '中', '畢', '業', '四', '、', '南', '投', '國', '中', '畢', '業', '五', '、', '平', '和', '國', '小', '畢', '業']
# [671, 510, 1298, 5836, 1920, 2119, 3180, 6879, 5052, 4415, 4777, 4955, 2792, 4525, 3511, 753, 510, 1298, 7274, 4906, 2825, 1920, 2119, 4525, 3511, 676, 510, 1298, 2832, 7770, 704, 4525, 3511, 1724, 510, 1298, 2832, 1751, 704, 4525, 3511, 758, 510, 2398, 1469, 1751, 2207, 4525, 3511]

# %% [markdown]
# ## jieba

# %%
import jieba
jieba.case_sensitive = True
text = '一、南華大學旅遊管理研究所畢業\n二、南開科技大學畢業\n三、南投高中畢業\n四、南投國中畢業\n五、平和國小畢業'
print('預設(精確模式) ： ')
print(jieba.lcut(text, cut_all=False, HMM=True))
print('--------------------------------------------------------------------------------------------------------------')
print('搜尋引擎模式 : ')
print(jieba.lcut_for_search(text)) # 搜尋引擎模式
# print('--------------------------------------------------------------------------------------------------------------')
# print('精確模式 : ')
# print(jieba.lcut(text, cut_all = False)) # 精確模式
# Out:
# 預設(精確模式) ：
# ['一', '、', '南華大學', '旅遊', '管理', '研究所', '畢業', '\n', '二', '、', '南開', '科技', '大學', '畢業', '\n', '三', '、', '南投', '高中', '畢業', '\n', '四', '、', '南投', '國中', '畢業', '\n', '五', '、', '平和', '國小', '畢業']
# --------------------------------------------------------------------------------------------------------------
# 搜尋引擎模式 :
# ['一', '、', '南華大學', '旅遊', '管理', '研究', '研究所', '畢業', '\n', '二', '、', '南開', '科技', '大學', '畢業', '\n', '三', '、', '南投', '高中', '畢業', '\n', '四', '、', '南投', '國中', '畢業', '\n', '五', '、', '平和', '國小', '畢業']

# %%
a = jieba.lcut(text, cut_all=False, HMM=True)
a
# Out:
# ['一',
#  '、',
#  '南華大學',
#  '旅遊',
#  '管理',
#  '研究所',
#  '畢業',
#  '\n',
#  '二',
#  '、',
#  '南開',
#  '科技',
#  '大學',
#  '畢業',
#  '\n',
#  '三',
#  '、',
#  '南投',
#  '高中',
#  '畢業',
#  '\n',
#  '四',
#  '、',
#  '南投',
#  '國中',
#  '畢業',
#  '\n',
#  '五',
#  '、',
#  '平和',
#  '國小',
#  '畢業']

# %%
df1 = pd.DataFrame({
        'Names': [
            'Roger Williams, Anne Graham',
            'Joe Smoe, Elliot Ezekiel',
            'Todd Roger'
         ]
    })
m = {
    'Roger Williams': 1234,
    'Joe Smoe': 898, 'Elliot Ezekiel': 8458, 'Todd Roger': 856
} #, 'Anne Graham': 4892

df1 = df1.replace(pd.Series(m).astype(str), regex=True)
df1
# Out:
#                Names
# 0  1234, Anne Graham
# 1          898, 8458
# 2                856

# %% [markdown]
# ### My data

# %%
def preprocess(question):
    words = jieba.cut(question) ## 精準模式
#     words = list(jieba.cut(question, cut_all=True)) ## 全斷詞模式
    return list(words)
df['words'] = df['學歷'].apply(preprocess)
df.head()
# Out:
#           地區 村里碼   姓名 號次 性別  出生年次        推薦政黨  得票數     得票率 當選註記 是否現任  \
# 0  南投縣南投市龍泉里   1  鄭木桂  1  男  1931  無黨籍及未經政黨推薦  526       1    1    是
# 1  南投縣南投市康壽里   2  田福川  1  男  1956  無黨籍及未經政黨推薦  312  0.3196    0    否
# 2  南投縣南投市康壽里   2  林華騰  2  男  1950  無黨籍及未經政黨推薦  396  0.4057    1    是
# 3  南投縣南投市康壽里   2  吳秋庚  3  男  1954  無黨籍及未經政黨推薦  268  0.2745    0    否
# 4  南投縣南投市三民里   3  蕭承倉  1  男  1961  無黨籍及未經政黨推薦  525       1    1    是
#
#           編碼                                                 學歷  \
# 0  370401011                                             南投國小畢業
# 1  370401021  一、南華大學旅遊管理研究所畢業\n二、南開科技大學畢業\n三、南投高中畢業\n四、南投國中畢...
# 2  370401022                                               元培醫專
# 3  370401023                                  和平國小\n南投縣投中\n明道高中
# 4  370401031                                     和平國小畢業\n南投國中畢業
# 2                             林x光檢驗中心負責人。\n南投市第19屆康壽里里長。
# 3                                            康壽里十七、十八屆里長
# 4        1.頂街頭地母委員會主任委員\n2.民防南投分隊顧問團榮譽團長\n3.17屆18屆里長現任里長
# ...                                                  ...
# 14501  第十二屆瓊埔村村長、第十五屆港口宮委員、第十七屆港口宮委員、第十八屆港口宮委員、現任瓊埔村順...
# 14502                           第18、19屆塭底村村長。港口宮管理委員會委員。
# 14503                                    後寮村17、18、19屆村長。
# 14504                                      15、16、17農會代表。
# 14505             1.水林鄉鄉民代表會第13.15.屆代表。2.水林鄉溪村第18.19屆村長。
#
#                                                       政見  \
# 0      （一）堅持熱誠服務態度\n（二）重視里內低收入戶及殘障弱勢里民之照顧\n（三）重視老人福利及...
# 1      一、設置關懷爆點,積極關懷·里內獨居老人,外配,愛族的起\n居生活,並辦理里民社會急難救助,...
# 2                     專職里長。\n有事不必到我家，打手機到府服務： 0918629668
# 3                              協助弱勢里民，反應里民所需，維護改善里內居家環境。
# 4      1、敦親睦鄰,促進里和諧。\n2、爭取建設,力求里民福利。\n3、熱心服務,關照老弱婦孺。\...
# ...                                                  ...
# 14501  一、呷咱瓊埔村鄉親大家站在一起向鄉、縣政府争取地方建設。二、加強社區全面監視系統以維護地方財...
# 14502  一、監督新建村民集會所之工程進度與品質。二、積極爭取新建集會所之內部各項設施經費。三、落實產...
# 14503                          爭取地方建設、服務村民、綠美化社區、促進地方和諧。
# 14504        一、服務村民。二、水道路修護。三、整理環境衛生。四、關心老人與福利。五、促進社區發展。
# 14505  1.配合公所之政令推動。2.定期消毒及疏通村內水溝,確保環境衛生及提升村民生活品質。3.舉辦...
#
#                                                    words
# 0                                                南投,2,畢業
# 1      一,、,南華5,旅遊,管理,6,畢業,\n,二,、,南開,科技,5,畢業,\n,三,、,南投...
# 2                                                  元培,醫專
# 3                               和平,2,\n,南投,縣,投中,\n,明,道,3
# 4                                     和平,2,畢業,\n,南投,2,畢業
# ...                                                  ...
# 14501                                         中興國,小,畢業,。
# 14502                                            中興國,小,。
# 14503                                         水林國,中,畢業,。
# 14504                                           和,安國,小,。
# 14505                                         水林國,中,畢業,。
#
# [14506 rows x 16 columns]

# %%
#只保留數字
df['words'] = df.words.str.extract('(\d+)') #.astype(int) df.A.str.extract('(\d+)')
df
# Out:
#               地區 村里碼   姓名 號次 性別  出生年次        推薦政黨  得票數     得票率 當選註記 是否現任  \
# 0      南投縣南投市龍泉里   1  鄭木桂  1  男  1931  無黨籍及未經政黨推薦  526       1    1    是
# 1      南投縣南投市康壽里   2  田福川  1  男  1956  無黨籍及未經政黨推薦  312  0.3196    0    否
# 2      南投縣南投市康壽里   2  林華騰  2  男  1950  無黨籍及未經政黨推薦  396  0.4057    1    是
# 3      南投縣南投市康壽里   2  吳秋庚  3  男  1954  無黨籍及未經政黨推薦  268  0.2745    0    否
# 4      南投縣南投市三民里   3  蕭承倉  1  男  1961  無黨籍及未經政黨推薦  525       1    1    是
# ...          ...  ..  ... .. ..   ...         ...  ...     ...  ...  ...
# 14505  1.配合公所之政令推動。2.定期消毒及疏通村內水溝,確保環境衛生及提升村民生活品質。3.舉辦...   NaN
#
# [14506 rows x 16 columns]

# %%
#計算nan數量
total_nan_values = df['words'].isnull().sum().sum()
print ('nan數量 : ',total_nan_values)
# Out:
# nan數量 :  6608

# %% [markdown]
# ## 直接文字替換
# class_mapping = { '研究所':6, '大學':5, '專科':4,'高中':3,'高職' :3,'國中' : 2 ,'國小':2} #最後無數字者 歸為1（國小以下）

# %%
import pandas as pd
df = pd.read_csv("103-two_compare.csv") 
df
# Out:
#              地區  村里碼   姓名  號次 性別  出生年次        推薦政黨   得票數     得票率  當選註記 是否現任  \
# 0     南投縣南投市平和里   12  謝清輝   1  男  1950  無黨籍及未經政黨推薦  1883  0.5122     1    是
# 1     南投縣南投市平和里   12  曾聰明   2  男  1951  無黨籍及未經政黨推薦  1793  0.4877     0    否
# 2     南投縣南投市三和里   16  謝銘津   1  男  1951  無黨籍及未經政黨推薦   959  0.4892     0    否
# 3     南投縣南投市三和里   16  吳志鵬   2  男  1961  無黨籍及未經政黨推薦  1001  0.5107     1    是
# 4     南投縣南投市嘉興里   17  張燈示   1  男  1954  無黨籍及未經政黨推薦   522  0.3546     0    否
# ...         ...  ...  ...  .. ..   ...         ...   ...     ...   ...  ...
# 7403  雲林縣水林鄉大溝村   14  李聯勝   2  男  1942  無黨籍及未經政黨推薦   431  0.5561     1    是
# 7404  雲林縣水林鄉松北村   18  陳永祥   1  男  1953  無黨籍及未經政黨推薦   564  0.7203     1    是
# 7405  雲林縣水林鄉松北村   18  黃永成   2  男  1953  無黨籍及未經政黨推薦   219  0.2796     0    否
# 7406  雲林縣水林鄉溪墘村   24  蔡錦明   1  男  1951  無黨籍及未經政黨推薦   325  0.4887     0    否
# 7407  雲林縣水林鄉溪墘村   24  高文彬   2  男  1959  無黨籍及未經政黨推薦   340  0.5112     1    是
#
#              編碼                            學歷  \
# 0     370401121  南投市平和國小\n中興國中\n私立宜寧高中機工科畢業夜校
# 1     370401122             南投市平和國小\n陸軍第二士官學校
# 2     370401161        南投國小\n南投初中\n陸軍第一士校高中畢業
# 3     370401162            南投國小\n南投國中\n國立南投高商
# 4     370401171         嘉和國小\n南投高中初級部\n沙鹿高工畢業
# ...         ...                           ...
# 7403  370520142                       嘉義高農肄業。
# 7404  370520181                       蔦松國小畢業。
# 7405  370520182                       蔦松國小畢業。
# 7406  370520241                         和安國小。
# 7407  370520242                       水林國中畢業。
#
#                                                      經歷  \
# 0     1、南投市平和里第17、18 、19屆里長\n2、中宏有限公司課長\n3、南投縣總上會上級代...
# 1                                   天明宮主任委員\n平和社區發展協會理事
# 2     重興建材行。\n南投縣建材公會理事長。\n南投縣謝姓宗親會理事長。\n南投市三和社區發展協會...
# 3     現任里長\n南投市農會農事小組長\n南投市農會代表\n南投市農會理事\n南投市義消分隊隊員\...
# 4     一、南投市後備軍人輔導中心輔導員\n二、南投國際青年商會會員、OB會友。\n三、彰化汽車客運...
# ...                                                 ...
# 7403                                水林鄉第十七、十八、十九當選大溝村長。
# 7404                               松北村第16屆村長。松北村第19屆村長。
# 7405                                       蔦松國小42屆家長會長。
# 7406                                      15、16、17農會代表。
# 7407             1.水林鄉鄉民代表會第13.15.屆代表。2.水林鄉溪村第18.19屆村長。
#
#                                                      政見
# 0     一、維持專責呈長邢秤，為呈民服務，做好呈政事務。\n二、繼續關懷弱勢族群，辦受理老人、屮低收...
# 1                           熱心為里社區爭福利\n為守望相助爭福利\n認真服務里民
# 2     一專職服務，認真工作，建設里社區。\n二燈要亮，路要平，水要通及增設防盜系統。\n三、關心婦...
# 3     1 、推行政令、反映民意。\n2 、推動里民文康、休閒自強活動促進里民感情。\n3 、代辦各...
# 4     一、提昇里民耕作農作物、園藝、栽植管理知識，不定期聘請專業人員授課講習、期使本少利多效率·\...
# ...                                                 ...
# 7403                                           服務村民為目的。
# 7404  一、全心全力為村民服務。二、主動認真勤快爭取地方建設。三、加強美綠化工程,改善居民居住品質及環境。
# 7405                   一、爭取村內農水路。二、爭取老人弱勢福利。三、爭取社區老人福利。
# 7406        一、服務村民。二、水道路修護。三、整理環境衛生。四、關心老人與福利。五、促進社區發展。
# 7407  1.配合公所之政令推動。2.定期消毒及疏通村內水溝,確保環境衛生及提升村民生活品質。3.舉辦...
#
# [7408 rows x 15 columns]

# %%
#研究所
df2 = df.copy()
df2['學歷'].loc[df2['學歷'].str.contains('研究所')] = "6" #, '學歷'
# Out:
# /home/coco31429/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
#大學
df2['學歷'].loc[df2['學歷'].str.contains('大學')] = "5"

# %%
# 專科 
df2['學歷'].loc[df2['學歷'].str.contains('專科')] = "4"

# %%
#'高中':3 #'高職' :3
df2['學歷'].loc[df2['學歷'].str.contains('高中')] = "3"
df2['學歷'].loc[df2['學歷'].str.contains('高職')] = "3"

# %%
# '國中' : 2  '國小':2
df2['學歷'].loc[df2['學歷'].str.contains('國中')] = "2"
df2['學歷'].loc[df2['學歷'].str.contains('國小')] = "2"

# %%
print('學歷六大類：')
print('研究所(6)人數：',len(df2[df2['學歷'] == "6"]))
print('大學(5)人數：',len(df2[df2['學歷'] == "5"]))
print('專科(4)人數：',len(df2[df2['學歷'] == "4"]))
print('高中,高職(3)人數：',len(df2[df2['學歷'] == "3"]))
print('國中,國小(2)人數：',len(df2[df2['學歷'] == "2"]))
print('目前無編號人數：',len(df2[(df2['學歷'] != '1') & (df2['學歷'] != '2') & (df2['學歷'] != '3') & (df2['學歷'] != '4') & (df2['學歷'] != '5') & (df2['學歷'] != '6')]))
# Out:
# 學歷六大類：
# 研究所(6)人數： 54
# 大學(5)人數： 500
# 專科(4)人數： 639
# 高中,高職(3)人數： 2052
# 國中,國小(2)人數： 3988
# 目前無編號人數： 159

# %% [markdown]
# 無編號繼續處理

# %%
df2['學歷'].loc[df2['學歷'].str.contains('碩士')] = "6"
df2['學歷'].loc[df2['學歷'].str.contains('台北師範|師範學院|中正理工學院土木系畢業')] = "5"
df2['學歷'].loc[df2['學歷'].str.contains('醫專|校專|工專|農工|商專|師專|技術學院|專料|農專|軍官學校|陸軍政工|護專|專修班|企專|體專|二專')] = "4"
# ...                                                 ...
# 6710                    1.海軍陸戰隊少校2.永慶不動產經理3.榮民服務處大寮服務組長
# 6738                  高雄縣仁武鄉仁福村第十七屆、十八屆村長高雄市仁武區仁福里第一屆里長
# 6763                            政戰學校研究班五十三期空軍上校主任退役現任里長
# 6802  1.排、連長、油庫主任。2.慈濟環保志工。3.義大醫院志工。4.角宿社區發展協會理事長兼環保...
# 6810            1.田寮鄉南安村第15、16、17、 18屆村長。2.田寮區南安里第1屆里長。
#
#                                                      政見
# 195   (1)傾聽及整合鄉親意見，結合鄉親力量，積極爭\n取經費，加強改善地方建設，促進鄉親生活圈\...
# 366   積極爭取華光計畫區內興建錦泰里多功能里民活動中心。建請政府將錦泰里內殘破不堪舊房舍闢建公園綠...
# 394   1爭取太陽能發電站、設立本里里民電動機車免付費使用2增加夜間巡守隊設備。新人新政、無黨無派建...
# 405   1.完善社區發展協會照顧關懷據點_x0007_例：單身家庭特殊照護、醫師健康講座以及社區關懷...
# 408   服務的信念：【步步履履為鄉里、點點滴滴行公益】‧\t營造優良活動空間，賡續推動社區兒童教育，...
# ...                                                 ...
# 6710  1.垃圾場回饋金透明化，帳目公佈。2.回饋金全數用在里民不作私人饋贈。3.爭取居住國有財產局...
# 6738  一.熱心地做個專職的里長，全心全力為仁福里里民服務。二.融合里民的感情、做好守望相助的工作，...
# 6763  一、爭取大勇街後半段拓寬工程。二、爭取柳橋西路二段納入都市計畫。三、爭取協和路大水溝全線加蓋...
# 6802  1.全力協助辦好每年之南路媽文化季活動，並結合大學城都市計畫，促進角宿社區再發展、再繁榮。2...
# 6810          1.全心全力為里民服務。2.積極爭取里內建設。3.配合市政府區公所為里民謀求福祉。
#
# [159 rows x 15 columns]

# %% [markdown]
# ## 先捨棄作分類器

# %%
df3 = df2[~((df2['學歷'] != '1') & (df2['學歷'] != '2') & (df2['學歷'] != '3') & (df2['學歷'] != '4') & (df2['學歷'] != '5') & (df2['學歷'] != '6'))]
df3
# Out:
#              地區  村里碼   姓名  號次 性別  出生年次        推薦政黨   得票數     得票率  當選註記 是否現任  \
# 0     南投縣南投市平和里   12  謝清輝   1  男  1950  無黨籍及未經政黨推薦  1883  0.5122     1    是
# 1     南投縣南投市平和里   12  曾聰明   2  男  1951  無黨籍及未經政黨推薦  1793  0.4877     0    否
# 2     南投縣南投市三和里   16  謝銘津   1  男  1951  無黨籍及未經政黨推薦   959  0.4892     0    否
# 3     南投縣南投市三和里   16  吳志鵬   2  男  1961  無黨籍及未經政黨推薦  1001  0.5107     1    是
# 4     南投縣南投市嘉興里   17  張燈示   1  男  1954  無黨籍及未經政黨推薦   522  0.3546     0    否
# ...         ...  ...  ...  .. ..   ...         ...   ...     ...   ...  ...
# 7403  雲林縣水林鄉大溝村   14  李聯勝   2  男  1942  無黨籍及未經政黨推薦   431  0.5561     1    是
# 7404  雲林縣水林鄉松北村   18  陳永祥   1  男  1953  無黨籍及未經政黨推薦   564  0.7203     1    是
# 7405  雲林縣水林鄉松北村   18  黃永成   2  男  1953  無黨籍及未經政黨推薦   219  0.2796     0    否
# 7406  雲林縣水林鄉溪墘村   24  蔡錦明   1  男  1951  無黨籍及未經政黨推薦   325  0.4887     0    否
# 7407  雲林縣水林鄉溪墘村   24  高文彬   2  男  1959  無黨籍及未經政黨推薦   340  0.5112     1    是
#
#              編碼 學歷                                                 經歷  \
# 0     370401121  3  1、南投市平和里第17、18 、19屆里長\n2、中宏有限公司課長\n3、南投縣總上會上級代...
# 1     370401122  2                                天明宮主任委員\n平和社區發展協會理事
# 2     370401161  3  重興建材行。\n南投縣建材公會理事長。\n南投縣謝姓宗親會理事長。\n南投市三和社區發展協會...
# 3     370401162  2  現任里長\n南投市農會農事小組長\n南投市農會代表\n南投市農會理事\n南投市義消分隊隊員\...
# 4     370401171  3  一、南投市後備軍人輔導中心輔導員\n二、南投國際青年商會會員、OB會友。\n三、彰化汽車客運...
# ...         ... ..                                                ...
# 7403  370520142  3                                水林鄉第十七、十八、十九當選大溝村長。
# 7404  370520181  2                               松北村第16屆村長。松北村第19屆村長。
# 7405  370520182  2                                       蔦松國小42屆家長會長。
# 7406  370520241  2                                      15、16、17農會代表。
# 7407  370520242  2             1.水林鄉鄉民代表會第13.15.屆代表。2.水林鄉溪村第18.19屆村長。
#
#                                                      政見
# 0     一、維持專責呈長邢秤，為呈民服務，做好呈政事務。\n二、繼續關懷弱勢族群，辦受理老人、屮低收...
# 1                           熱心為里社區爭福利\n為守望相助爭福利\n認真服務里民
# 2     一專職服務，認真工作，建設里社區。\n二燈要亮，路要平，水要通及增設防盜系統。\n三、關心婦...
# 3     1 、推行政令、反映民意。\n2 、推動里民文康、休閒自強活動促進里民感情。\n3 、代辦各...
# 4     一、提昇里民耕作農作物、園藝、栽植管理知識，不定期聘請專業人員授課講習、期使本少利多效率·\...
# ...                                                 ...
# 7403                                           服務村民為目的。
# 7404  一、全心全力為村民服務。二、主動認真勤快爭取地方建設。三、加強美綠化工程,改善居民居住品質及環境。
# 7405                   一、爭取村內農水路。二、爭取老人弱勢福利。三、爭取社區老人福利。
# 7406        一、服務村民。二、水道路修護。三、整理環境衛生。四、關心老人與福利。五、促進社區發展。
# 7407  1.配合公所之政令推動。2.定期消毒及疏通村內水溝,確保環境衛生及提升村民生活品質。3.舉辦...
#
# [7239 rows x 15 columns]

# %%
# df3 = df.copy()
df_test = df3.groupby(["地區"]).出生年次.describe()
df3['year'] = df3['地區'].map(dict(zip(df_test.index,df_test['mean'])))
fliter1 = (df3['出生年次'] > df3["year"]) #年長 df[fliter1]
fliter2 = (df3['出生年次'] < df3["year"]) #年幼 df[fliter2]
fliter3 = (df3['出生年次'] == df3["year"]) #同年 df[fliter3]
# 男=1 女=0 
df3['性別'].replace("男",1,inplace=True)
df3['性別'].replace("女",0,inplace=True)
# 有政黨=1 無政黨=0
df3['推薦政黨'].replace(['中國國民黨', '民主進步黨','台灣團結聯盟','人民民主陣線','親民黨','中華統一促進黨','無黨團結聯盟','新黨','青年陽光黨','人民民主黨','中華文化民主黨','農民黨','樹黨','時代力量','全國人民黨','左翼聯盟','華裔和合黨','正義聯盟','台灣學習黨','中華民族致公黨','天宙和平統一家庭黨'],1,inplace=True)
df3['推薦政黨'].replace('無黨籍及未經政黨推薦',0,inplace=True)
# 現任=1 無現任=0
df3['是否現任'].replace("是",1,inplace=True)
df3['是否現任'].replace("否",0,inplace=True)
# 年長=2 年幼=1 同歲=0
df3.loc[fliter1,'年紀'] = 2
df3.loc[fliter2,'年紀'] = 1
df3.loc[fliter3,'年紀'] = 0
df3
# Out:
#              地區  村里碼   姓名  號次  性別  出生年次  推薦政黨   得票數     得票率  當選註記  是否現任  \
# 0     臺北市松山區富錦里    5  李煥中   1   1  1967     1  1636  0.6111     1     0
# 1     臺北市松山區富錦里    5  江雪花   2   0  1952     1  1041  0.3888     0     0
# 2     臺北市松山區精忠里    9  廖世雄   1   1  1968     0  1047  0.4572     0     0
# 3     臺北市松山區精忠里    9  賴美旭   2   0  1970     1  1243  0.5427     1     0
# 4     臺北市松山區東昌里   12  陳志明   1   1  1961     1  1017  0.6825     1     1
# ...         ...  ...  ...  ..  ..   ...   ...   ...     ...   ...   ...
# 7245  新竹市香山區大湖里   18  曾一德   2   1  1976     0   379  0.5777     1     0
# 7246  新竹市香山區內湖里   21  鄭潮木   1   1  1966     0  1245  0.4760     0     0
# 7247  新竹市香山區內湖里   21  王斌展   2   1  1963     0  1370  0.5239     1     1
# 7248  新竹市香山區南港里   23  林木吉   1   1  1947     0   209  0.3365     0     1
# 7249  新竹市香山區南港里   23  林武鍾   2   1  1968     0   412  0.6634     1     0
#
#              編碼                                                 學歷  \
# 0     710001051                   東海大學社會學系省立岡山高級中學高雄市立五福國中高雄縣立岡山國小
# 1     710001052                                     臺灣省立臺北師範專科學校畢業
# 2     710001091             稻江科技大學境外EMBA企業管理碩士專班畢業專科學校畢業家事類美容造型設計科
# 3     710001092                           二水國小二水國中省立彰化高商國立台北商業專科學校
# 4     710001121                                       民生國小介壽國中憲兵學校
# ...         ...                                                ...
# 7245  771303182                                                國中畢
# 7246  771303211  1._x0007_新竹市立內湖國小2._x0007_新竹市立香山國中3._x0007_親民技...
# 7247  771303212                                              ①高職畢業
# 7248  771303231                                               國小畢業
# 7249  771303232                                    內湖國小、香山國中、君毅高中、
#
#                                                      經歷  \
# 0     臺北市議員陳孋輝辦公室主任臺北市民生社區商圈發展協會理事長臺北市富民生態環境保育學會理事長銘...
# 1            1私立旭光幼兒園園長。2富錦里11鄰鄰長。3富錦社區發展協會理事長。4富錦里巡守隊。
# 2         世紀精緻國際美髮商行負責人。台北市理燙髮職業工會現任常務理事。擔任國家男子乙丙級檢定評審。
# 3     台北市彩霞教育基金會音樂帶領講師中華民國健身運動協會樂齡健身運動指導員花蓮門諾醫院音樂帶領工...
# 4     臺北市松山區東昌里第9屆、10屆、11屆、12屆(專職里長)。中華血液基金會130次以上(全...
# ...                                                 ...
# 7245                       1.食品加工負責人2._x0007_金教岩管理委員會委員
# 7246                                       新竹市前市議員林漢淇助理
# 7247  ①_x0007_前新竹市議員王明魁歷任助理②_x0007_內湖里19、20屆里長③_x000...
# 7248           第十七、十九、二十屆南港里長新竹市林姓宗親會第十一屆副理事長第六屆南港社區理事長
# 7249  新竹市南港社區發展常務理事。新竹市南港里南華宮副主委。新竹市內湖國小家長委員。新竹市南寮義消...
#
#                                                      政見    year   年紀
# 0     新富錦新願景1、提升環境品質－全里汙水管及防火巷鋪面全面更新。2、建置安全居家－與社會局、警...  1959.5  2.0
# 1     1、成立合法警察局核准之守望相助隊以保護里內安全。2、關懷婦女，並不定期舉辦親子教育活動。3...  1959.5  1.0
# 2     1、維護社區環境陣容：推動社區《節能減碳》、《綠色環保》。2、督促社區守望相助隊，結合警察機...  1969.0  1.0
# 3     持續推動里政，從課程學習、節慶活動、社區關懷到社區的每一個角落。●協助里民電梯或樓梯附掛式升...  1969.0  2.0
# 4     1、廣設【AED】生命防護系統。2、設置里民活動場所，舉辦敦親睦鄰、康樂聯誼活動。3、擴編巡...  1965.0  1.0
# ...                                                 ...     ...  ...
# 7245                              一、熱心服務。二、爭取建設。三、造福大湖。  1974.5  2.0
# 7246                                         朝朝暮暮，為您服務！  1964.5  2.0
# 7247        ①盡心爭建設，用心來服務。②歷練八年經驗，了解內湖未來。③持續爭取建設，永續內湖發展。  1964.5  1.0
# 7248                     不分黨派、腳踏實地。為民服務、勤快好叫。里內和氣、懇請賜票。  1957.5  1.0
# 7249  1.多爭取經費，建設繁榮南港。2.風車回饋金一律公開透明。3.服務不分區域，共創和諧南港。4...  1957.5  2.0
#
# [7250 rows x 17 columns]

# %%
df3.drop(columns=['地區','村里碼','姓名','出生年次','得票數','得票率','編碼','經歷','政見','year'],inplace=True) #,'unique','學歷'
df3
# Out:
#       號次  性別  推薦政黨  當選註記  是否現任   年紀
# 0      1   1     1     1     0  2.0
# 1      2   0     1     0     0  1.0
# 2      1   1     0     0     0  1.0
# 3      2   0     1     1     0  2.0
# 4      1   1     1     1     1  1.0
# ...   ..  ..   ...   ...   ...  ...
# 7245   2   1     0     1     0  2.0
# 7246   1   1     0     0     0  2.0
# 7247   2   1     0     1     1  1.0
# 7248   1   1     0     0     1  1.0
# 7249   2   1     0     1     0  2.0
#
# [7250 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
model = SVC()

df_ = df3[['號次','性別','推薦政黨','是否現任','學歷','年紀']] #,'學歷'
X = df_
y = df3['當選註記']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=101)
model.fit(X_train,y_train)
predictions = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[550 183]
#  [255 462]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.75      0.72       733
#            1       0.72      0.64      0.68       717
#
#     accuracy                           0.70      1450
#    macro avg       0.70      0.70      0.70      1450
# weighted avg       0.70      0.70      0.70      1450

# %% [markdown]
# ### 連任捨棄作分析

# %%
import pandas as pd
df4 = pd.read_csv("103-two_compare.csv") 
df4_ = df4.groupby(["地區"]).是否現任.describe()
df4['unique'] = df4['地區'].map(dict(zip(df4_.index,df4_['unique']))) 
df4_ans = df4[df4['unique']==1] #1:拿掉一組有連任 2：拿掉整組皆無連任
# 21    1.爭取社區基礎建設與設施，美化環境·提升居住之生活品質。\n2.主動關懷老弱掃孺，弱勢族群...       1
# 28    1.爭取社區基礎建設與設施，美化環境·提升居住之生活品質。\n2.主動關懷老弱掃孺，弱勢族群...       1
# 29    1.爭取社區基礎建設與設施，美化環境·提升居住之生活品質。\n2.主動關懷老弱掃孺，弱勢族群...       1
# 76                                       爭取社區建設，觀光農業並進。       1
# ...                                                 ...     ...
# 7343                   爭取村里建設、協助村民辦理各項補助、改善村內環境衛生及生活品質。       1
# 7364  一、提供社區弱勢教育福利。二、照顧弱勢老人醫療服務品質。三、建設公共設施,以村民福利為指標。...       1
# 7365                 關懷老人、兒童及弱勢村民。爭取蚵寮村應有之地方建設。支持教育之推廣。       1
# 7372  一、協助政府推行政令。二、結合天台宮管理委員會及社區發展協會,積極推動政務及文化建設。三、配...       1
# 7373        關懷老人,爭取老人福利。一人當選,全家服務。服務村民,爭取建設經費。提升村民生活品質。       1
#
# [1290 rows x 16 columns]

# %%
df4_ans['學歷'].loc[df4_ans['學歷'].str.contains('研究所|碩士')] = "6"
df4_ans['學歷'].loc[df4_ans['學歷'].str.contains('大學|台北師範|師範學院|中正理工學院土木系畢業')] = "5"
df4_ans['學歷'].loc[df4_ans['學歷'].str.contains('專科|醫專|校專|工專|農工|商專|師專|技術學院|機械學校|海軍通信電子學校|警察學校|專料|農專|軍官學校|陸軍士官學校|陸軍政工|護專|陸軍第二士校')] = "4"
df4_ans['學歷'].loc[df4_ans['學歷'].str.contains('高中|高職|高商|商工|高級農工|高工|工商|職業學校|高農|高級中學|商職|農校|附工|家商|高級|工家')] = "3"
df4_ans['學歷'].loc[df4_ans['學歷'].str.contains('國中|國小|國民小學|初中|初商|初級中學|國民學校|國民中學|國校|中學|初農|國民|岡中|小學')] = "2"
df4_ans['學歷'].loc[df4_ans['學歷'].str.contains('無')] = "1"
df4_ans = df4_ans[~((df4_ans['學歷'] != '1') & (df4_ans['學歷'] != '2') & (df4_ans['學歷'] != '3') & (df4_ans['學歷'] != '4') & (df4_ans['學歷'] != '5') & (df4_ans['學歷'] != '6'))]

df4_ans
# Out:
# /home/coco31429/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#              地區  村里碼   姓名  號次 性別  出生年次        推薦政黨  得票數     得票率  當選註記 是否現任  \
# 20    南投縣南投市光輝里   34  洪靜宗   1  男  1968  無黨籍及未經政黨推薦  167  0.4489     0    否
# 21    南投縣南投市光輝里   34  沈玉珠   2  女  1959  無黨籍及未經政黨推薦  205  0.5510     1    否
# 28    南投縣埔里鎮北門里    4  黃樹興   1  男  1949  無黨籍及未經政黨推薦  683  0.4697     0    否
# 29    南投縣埔里鎮北門里    4  陳進萬   2  男  1954       中國國民黨  771  0.5302     1    否
# 76    南投縣草屯鎮雙冬里   22  曾明正   1  男  1965  無黨籍及未經政黨推薦  598  0.3705     0    否
# ...         ...  ...  ...  .. ..   ...         ...  ...     ...   ...  ...
# 7343  雲林縣四湖鄉施湖村    6  何秀珍   2  女  1960  無黨籍及未經政黨推薦  282  0.3294     0    否
# 7364  雲林縣口湖鄉蚵寮村    7  陳玉釵   1  女  1956  無黨籍及未經政黨推薦  516  0.4791     0    否
# 7365  雲林縣口湖鄉蚵寮村    7  林彥銘   2  男  1967  無黨籍及未經政黨推薦  561  0.5208     1    否
# 7372  雲林縣口湖鄉台子村   14  林志昇   1  男  1956  無黨籍及未經政黨推薦  612  0.4872     0    否
# 7373  雲林縣口湖鄉台子村   14  緱梅琳   2  女  1963  無黨籍及未經政黨推薦  644  0.5127     1    否
#
#              編碼 學歷                                                 經歷  \
# 20    370401341  5                  中興義消分隊副小隊長\n山腳守望相助隊隊長\n泰業電信器材行負責人
# 21    370401342  3                       一、南投縣中興鳳凰志工分隊顧問\n二、雅荷坊美食館負責人
# 28    370402041  3                       一、南投縣中興鳳凰志工分隊顧問\n二、雅荷坊美食館負責人
# 29    370402042  3                       一、南投縣中興鳳凰志工分隊顧問\n二、雅荷坊美食館負責人
# 76    370403221  2                        雙冬國小六十週年慶家長會長。\n雙冬社區發展協會理事。
# ...         ... ..                                                ...
# 7343  370518062  2                        1.四湖鄉調解委員會委員。2.施湖社區發展協會理事長。
# 7364  370519071  5  崇文國民學校、媽媽教室、組長、會長、崇文婦女協會第一二屆理事長。蚵寮村,第18屆村長、蚵寮社...
# 7365  370519072  3                          崇文國小家長會會長。蚵寮順天宮管理委員會常務委員。
# 7372  370519141  2  一、台子村第18屆村長。二、天台宮管理委員會委員、副主任委員。三、台子村社區發展協會理事、常...
# 7373  370519142  3                                                 無。
#
#                                                      政見  unique
# 20    1 、配合政府實施「六星計劃」改善治安、環境、人文、環保、觀光、產業為目標。\n2、舉辦里民...       1
# 21    1.爭取社區基礎建設與設施，美化環境·提升居住之生活品質。\n2.主動關懷老弱掃孺，弱勢族群...       1
# 28    1.爭取社區基礎建設與設施，美化環境·提升居住之生活品質。\n2.主動關懷老弱掃孺，弱勢族群...       1
# 29    1.爭取社區基礎建設與設施，美化環境·提升居住之生活品質。\n2.主動關懷老弱掃孺，弱勢族群...       1
# 76                                       爭取社區建設，觀光農業並進。       1
# ...                                                 ...     ...
# 7343                   爭取村里建設、協助村民辦理各項補助、改善村內環境衛生及生活品質。       1
# 7364  一、提供社區弱勢教育福利。二、照顧弱勢老人醫療服務品質。三、建設公共設施,以村民福利為指標。...       1
# 7365                 關懷老人、兒童及弱勢村民。爭取蚵寮村應有之地方建設。支持教育之推廣。       1
# 7372  一、協助政府推行政令。二、結合天台宮管理委員會及社區發展協會,積極推動政務及文化建設。三、配...       1
# 7373        關懷老人,爭取老人福利。一人當選,全家服務。服務村民,爭取建設經費。提升村民生活品質。       1
#
# [1271 rows x 16 columns]

# %%
df_test = df4_ans.groupby(["地區"]).出生年次.describe()
df4_ans['year'] = df4_ans['地區'].map(dict(zip(df_test.index,df_test['mean'])))
fliter1 = (df4_ans['出生年次'] > df4_ans["year"]) #年長 df[fliter1]
fliter2 = (df4_ans['出生年次'] < df4_ans["year"]) #年幼 df[fliter2]
fliter3 = (df4_ans['出生年次'] == df4_ans["year"]) #同年 df[fliter3]
# 男=1 女=0 
df4_ans['性別'].replace("男",1,inplace=True)
df4_ans['性別'].replace("女",0,inplace=True)
# 有政黨=1 無政黨=0
df4_ans['推薦政黨'].replace(['中國國民黨', '民主進步黨','台灣團結聯盟','人民民主陣線','親民黨','中華統一促進黨','無黨團結聯盟','新黨','青年陽光黨','人民民主黨','中華文化民主黨','農民黨','樹黨','時代力量','全國人民黨','左翼聯盟','華裔和合黨','正義聯盟','台灣學習黨','中華民族致公黨','天宙和平統一家庭黨'],1,inplace=True)
df4_ans['推薦政黨'].replace('無黨籍及未經政黨推薦',0,inplace=True)
# 現任=1 無現任=0
df4_ans['是否現任'].replace("是",1,inplace=True)
df4_ans['是否現任'].replace("否",0,inplace=True)
# 年長=2 年幼=1 同歲=0
df4_ans.loc[fliter1,'年紀'] = 2
df4_ans.loc[fliter2,'年紀'] = 1
df4_ans.loc[fliter3,'年紀'] = 0
df4_ans
# Out:
# /tmp/ipykernel_3698937/3162673929.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4_ans['year'] = df4_ans['地區'].map(dict(zip(df_test.index,df_test['mean'])))
# /home/coco31429/.local/lib/python3.8/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# /home/coco31429/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /home/coco31429/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#              地區  村里碼   姓名  號次  性別  出生年次  推薦政黨  得票數     得票率  當選註記  是否現任  \
# 20    南投縣南投市光輝里   34  洪靜宗   1   1  1968     0  167  0.4489     0     0
# 21    南投縣南投市光輝里   34  沈玉珠   2   0  1959     0  205  0.5510     1     0
# 28    南投縣埔里鎮北門里    4  黃樹興   1   1  1949     0  683  0.4697     0     0
# 29    南投縣埔里鎮北門里    4  陳進萬   2   1  1954     1  771  0.5302     1     0
# 76    南投縣草屯鎮雙冬里   22  曾明正   1   1  1965     0  598  0.3705     0     0
# ...         ...  ...  ...  ..  ..   ...   ...  ...     ...   ...   ...
# 7343  雲林縣四湖鄉施湖村    6  何秀珍   2   0  1960     0  282  0.3294     0     0
# 7364  雲林縣口湖鄉蚵寮村    7  陳玉釵   1   0  1956     0  516  0.4791     0     0
# 7365  雲林縣口湖鄉蚵寮村    7  林彥銘   2   1  1967     0  561  0.5208     1     0
# 7372  雲林縣口湖鄉台子村   14  林志昇   1   1  1956     0  612  0.4872     0     0
# 7373  雲林縣口湖鄉台子村   14  緱梅琳   2   0  1963     0  644  0.5127     1     0
#
#              編碼 學歷                                                 經歷  \
# 20    370401341  5                  中興義消分隊副小隊長\n山腳守望相助隊隊長\n泰業電信器材行負責人
# 21    370401342  3                       一、南投縣中興鳳凰志工分隊顧問\n二、雅荷坊美食館負責人
# 28    370402041  3                       一、南投縣中興鳳凰志工分隊顧問\n二、雅荷坊美食館負責人
# 29    370402042  3                       一、南投縣中興鳳凰志工分隊顧問\n二、雅荷坊美食館負責人
# 76    370403221  2                        雙冬國小六十週年慶家長會長。\n雙冬社區發展協會理事。
# ...         ... ..                                                ...
# 7343  370518062  2                        1.四湖鄉調解委員會委員。2.施湖社區發展協會理事長。
# 7364  370519071  5  崇文國民學校、媽媽教室、組長、會長、崇文婦女協會第一二屆理事長。蚵寮村,第18屆村長、蚵寮社...
# 7365  370519072  3                          崇文國小家長會會長。蚵寮順天宮管理委員會常務委員。
# 7372  370519141  2  一、台子村第18屆村長。二、天台宮管理委員會委員、副主任委員。三、台子村社區發展協會理事、常...
# 7373  370519142  3                                                 無。
#
#                                                      政見  unique    year   年紀
# 20    1 、配合政府實施「六星計劃」改善治安、環境、人文、環保、觀光、產業為目標。\n2、舉辦里民...       1  1963.5  2.0
# 21    1.爭取社區基礎建設與設施，美化環境·提升居住之生活品質。\n2.主動關懷老弱掃孺，弱勢族群...       1  1963.5  1.0
# 28    1.爭取社區基礎建設與設施，美化環境·提升居住之生活品質。\n2.主動關懷老弱掃孺，弱勢族群...       1  1951.5  1.0
# 29    1.爭取社區基礎建設與設施，美化環境·提升居住之生活品質。\n2.主動關懷老弱掃孺，弱勢族群...       1  1951.5  2.0
# 76                                       爭取社區建設，觀光農業並進。       1  1962.5  2.0
# ...                                                 ...     ...     ...  ...
# 7343                   爭取村里建設、協助村民辦理各項補助、改善村內環境衛生及生活品質。       1  1961.5  1.0
# 7364  一、提供社區弱勢教育福利。二、照顧弱勢老人醫療服務品質。三、建設公共設施,以村民福利為指標。...       1  1961.5  1.0
# 7365                 關懷老人、兒童及弱勢村民。爭取蚵寮村應有之地方建設。支持教育之推廣。       1  1961.5  2.0
# 7372  一、協助政府推行政令。二、結合天台宮管理委員會及社區發展協會,積極推動政務及文化建設。三、配...       1  1959.5  1.0
# 7373        關懷老人,爭取老人福利。一人當選,全家服務。服務村民,爭取建設經費。提升村民生活品質。       1  1959.5  2.0
#
# [1271 rows x 18 columns]

# %%
df4_ans.drop(columns=['地區','村里碼','姓名','出生年次','得票數','得票率','編碼','經歷','政見','year','unique','是否現任'],inplace=True) #,'unique','學歷'
df4_ans
# Out:
# /home/coco31429/.local/lib/python3.8/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#       號次  性別  推薦政黨  當選註記 學歷   年紀
# 20     1   1     0     0  5  2.0
# 21     2   0     0     1  3  1.0
# 28     1   1     0     0  3  1.0
# 29     2   1     1     1  3  2.0
# 76     1   1     0     0  2  2.0
# ...   ..  ..   ...   ... ..  ...
# 7343   2   0     0     0  2  1.0
# 7364   1   0     0     0  5  1.0
# 7365   2   1     0     1  3  2.0
# 7372   1   1     0     0  2  1.0
# 7373   2   0     0     1  3  2.0
#
# [1271 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
model = SVC()

df_ = df4_ans[['號次','性別','推薦政黨','學歷','年紀']] #,'學歷'
X = df_
y = df4_ans['當選註記']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=101)
model.fit(X_train,y_train)
predictions = model.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[65 54]
#  [59 77]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.55      0.53       119
#            1       0.59      0.57      0.58       136
#
#     accuracy                           0.56       255
#    macro avg       0.56      0.56      0.56       255
# weighted avg       0.56      0.56      0.56       255
